# %% [markdown]
# ## Orbitale des Wasserstoffatoms

# %%
import HOrbPlotter as hp

# %% [markdown]
# ### Hauptquantenzahl n=1
#
# Orbitale:
# - 1s Orbital (l=0)

# %%
hp.plot_Horbs(n=1)

# %% [markdown]
# ### Hauptquantenzahl n=2
#
# Orbitale:
# - 2s (l=0)
# - 2p (l=1)

# %%
hp.plot_Horbs(n=2)

# %% [markdown]
# ### Hauptquantenzahl n=3
#
# Orbitale:
# - 3s (l=0)
# - 3p (l=1)
# - 3d (l=2)

# %%
hp.plot_Horbs(n=3)

# %% [markdown]
# ### Hauptquantenzahl n=4
#
# Orbitale:
# - 4s (l=0)
# - 4p (l=1)
# - 4d (l=2)
# - 4f (l=3)

# %%
hp.plot_Horbs(n=4)
